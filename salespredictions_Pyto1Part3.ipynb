# %% [markdown]
# <a href="https://colab.research.google.com/github/CamillaCavallo/Proyecciones-ventas/blob/main/salespredictions_Pyto1Part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/clase data science/sales_predictions.csv'

# %%
df = pd.read_csv(filename)
df.head()
#Muestra la cabecera de la trama de datos
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# la data sí continene datos faltantes, para las columnas Weight y Size. teniendo 6113 datos con toda la información.

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
OutletSize_missing = df['Outlet_Size'].isna()
df.loc[OutletSize_missing,:]

#filas que contienen NAN de oulet size para ver si existe alguna relación. OUT 10, 17, y 45 al parecer no se sabe su tmaño.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 25                Household   45.9060            OUT017
# 28                    Dairy   45.5086            OUT010
# ...                     ...       ...               ...
# 8502              Household  216.4192            OUT045
# 8508  Fruits and Vegetables  199.4742            OUT045
# 8509  Fruits and Vegetables  213.9902            OUT010
# 8514                 Canned   57.5904            OUT045
# 8519           Baking Goods  108.1570            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 25                         2007         NaN               Tier 2
# 28                         1998         NaN               Tier 3
# ...                         ...         ...                  ...
# 8502                       2002         NaN               Tier 2
# 8508                       2002         NaN               Tier 2
# 8509                       1998         NaN               Tier 3
# 8514                       2002         NaN               Tier 2
# 8519                       2002         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 3         Grocery Store           732.3800
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 25    Supermarket Type1           838.9080
# 28        Grocery Store           178.4344
# ...                 ...                ...
# 8502  Supermarket Type1          3020.0688
# 8508  Supermarket Type1          2587.9646
# 8509      Grocery Store           424.7804
# 8514  Supermarket Type1           468.7232
# 8519  Supermarket Type1           549.2850
#
# [2410 rows x 12 columns]

# %%
import pandas as pd
import seaborn as sns
import numpy as np

corr_df = df.corr(method='pearson')

corr_df.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5ce0c_row0_col0, #T_5ce0c_row1_col1, #T_5ce0c_row2_col2, #T_5ce0c_row3_col3, #T_5ce0c_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5ce0c_row0_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5ce0c_row0_col2, #T_5ce0c_row4_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_5ce0c_row0_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_5ce0c_row0_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_5ce0c_row1_col0, #T_5ce0c_row1_col2, #T_5ce0c_row1_col3, #T_5ce0c_row1_col4, #T_5ce0c_row3_col0, #T_5ce0c_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5ce0c_row2_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5ce0c_row2_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_5ce0c_row2_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_5ce0c_row2_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_5ce0c_row3_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_5ce0c_row3_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_5ce0c_row3_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_5ce0c_row4_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_5ce0c_row4_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5ce0c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Item_Weight</th>
#       <th class="col_heading level0 col1" >Item_Visibility</th>
#       <th class="col_heading level0 col2" >Item_MRP</th>
#       <th class="col_heading level0 col3" >Outlet_Establishment_Year</th>
#       <th class="col_heading level0 col4" >Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ce0c_level0_row0" class="row_heading level0 row0" >Item_Weight</th>
#       <td id="T_5ce0c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5ce0c_row0_col1" class="data row0 col1" >-0.014048</td>
#       <td id="T_5ce0c_row0_col2" class="data row0 col2" >0.027141</td>
#       <td id="T_5ce0c_row0_col3" class="data row0 col3" >-0.011588</td>
#       <td id="T_5ce0c_row0_col4" class="data row0 col4" >0.014123</td>
#     </tr>
#     <tr>
#       <th id="T_5ce0c_level0_row1" class="row_heading level0 row1" >Item_Visibility</th>
#       <td id="T_5ce0c_row1_col0" class="data row1 col0" >-0.014048</td>
#       <td id="T_5ce0c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5ce0c_row1_col2" class="data row1 col2" >-0.001315</td>
#       <td id="T_5ce0c_row1_col3" class="data row1 col3" >-0.074834</td>
#       <td id="T_5ce0c_row1_col4" class="data row1 col4" >-0.128625</td>
#     </tr>
#     <tr>
#       <th id="T_5ce0c_level0_row2" class="row_heading level0 row2" >Item_MRP</th>
#       <td id="T_5ce0c_row2_col0" class="data row2 col0" >0.027141</td>
#       <td id="T_5ce0c_row2_col1" class="data row2 col1" >-0.001315</td>
#       <td id="T_5ce0c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5ce0c_row2_col3" class="data row2 col3" >0.005020</td>
#       <td id="T_5ce0c_row2_col4" class="data row2 col4" >0.567574</td>
#     </tr>
#     <tr>
#       <th id="T_5ce0c_level0_row3" class="row_heading level0 row3" >Outlet_Establishment_Year</th>
#       <td id="T_5ce0c_row3_col0" class="data row3 col0" >-0.011588</td>
#       <td id="T_5ce0c_row3_col1" class="data row3 col1" >-0.074834</td>
#       <td id="T_5ce0c_row3_col2" class="data row3 col2" >0.005020</td>
#       <td id="T_5ce0c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5ce0c_row3_col4" class="data row3 col4" >-0.049135</td>
#     </tr>
#     <tr>
#       <th id="T_5ce0c_level0_row4" class="row_heading level0 row4" >Item_Outlet_Sales</th>
#       <td id="T_5ce0c_row4_col0" class="data row4 col0" >0.014123</td>
#       <td id="T_5ce0c_row4_col1" class="data row4 col1" >-0.128625</td>
#       <td id="T_5ce0c_row4_col2" class="data row4 col2" >0.567574</td>
#       <td id="T_5ce0c_row4_col3" class="data row4 col3" >-0.049135</td>
#       <td id="T_5ce0c_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Outlet_Type'].unique() # para ver los tipos de tiendas
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
G2 = df.groupby(['Outlet_Type'])[['Outlet_Identifier']].nunique() #detalle tipos de tiendas
G2
# Out:
#                    Outlet_Identifier
# Outlet_Type
# Grocery Store                      2
# Supermarket Type1                  6
# Supermarket Type2                  1
# Supermarket Type3                  1

# %%
G3 = df.groupby(['Outlet_Type','Outlet_Identifier'])[['Outlet_Identifier']].nunique() #detalle tipos de tiendas
G3
# Out:
#                                      Outlet_Identifier
# Outlet_Type       Outlet_Identifier
# Grocery Store     OUT010                             1
#                   OUT019                             1
# Supermarket Type1 OUT013                             1
#                   OUT017                             1
#                   OUT035                             1
#                   OUT045                             1
#                   OUT046                             1
#                   OUT049                             1
# Supermarket Type2 OUT018                             1
# Supermarket Type3 OUT027                             1

# %%
#G2 = df.groupby(['Outlet_Identifier', 'Outlet_Size', 'Outlet_Type'])[['Outlet_Identifier']].nunique() #detalle tipos de tiendas
#G2

# %%
G2.plot.barh()
plt.title("Clasificación de tiendas")
plt.show()

# %%
#ventas por outlet
ventas = df.groupby(['Outlet_Identifier'])['Item_Outlet_Sales'].sum().sort_values()
ventas
# Out:
# Outlet_Identifier
# OUT019    1.796941e+05
# OUT010    1.883402e+05
# OUT018    1.851823e+06
# OUT045    2.036725e+06
# OUT046    2.118395e+06
# OUT013    2.142664e+06
# OUT017    2.167465e+06
# OUT049    2.183970e+06
# OUT035    2.268123e+06
# OUT027    3.453926e+06
# Name: Item_Outlet_Sales, dtype: float64

# %%
#ventas por canal

df2=df.groupby(['Outlet_Type'])[['Item_Outlet_Sales']].sum()
df2
# Out:
#                    Item_Outlet_Sales
# Outlet_Type
# Grocery Store           3.680343e+05
# Supermarket Type1       1.291734e+07
# Supermarket Type2       1.851823e+06
# Supermarket Type3       3.453926e+06

# %%
#media de ventas por canal

df3=df.groupby(['Outlet_Type'])[['Item_Outlet_Sales']].mean()
df3
# Out:
#                    Item_Outlet_Sales
# Outlet_Type
# Grocery Store             339.828500
# Supermarket Type1        2316.181148
# Supermarket Type2        1995.498739
# Supermarket Type3        3694.038558

# %%
fig1 = plt.figure(dpi=150)
ax = fig1.add_subplot(111)
ax = sns.barplot(y=ventas.index, x=ventas.values)



#ax.bar_label(ax.containers[0],fmt = '%d', fontsize=12, padding=4)
# Se definen el título y el label para el eje x
ax.set_title("Total Ventas por Outlet", {'fontsize': 10, 'fontweight':"bold"}, pad=20)
ax.set_xlabel("Ventas acumuladas (USD Millon)", fontsize= 10, labelpad=10)
ax.set_ylabel("")
plt.yticks(fontsize=9)
plt.xticks(fontsize=9)
# Out:
# (array([      0.,  500000., 1000000., 1500000., 2000000., 2500000.,
#         3000000., 3500000., 4000000.]),
#  <a list of 9 Text major ticklabel objects>)
